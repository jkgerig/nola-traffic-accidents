# %%
import numpy as np
import pandas as pd
import pickle
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from pprint import pprint
# Out:
# C:\Users\kgerig\miniconda3\envs\nola-traffic\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
data = pd.read_pickle('../../data/processed/all_samples.pickle')
data['datetime'] = pd.to_datetime(data.date)
data['day'] = data.datetime.dt.weekday_name
data = pd.get_dummies(data, prefix='day', columns=['day'])

# %%
features = ['hour',
            'daylight_yn',
            'holiday_yn',
            'rush_hour_yn',
            'temp',
            'wind_speed',
            'precipitation',
            'road_length',
            'class_freeway',
            'class_local',
            'class_major',
            'class_other',
            'class_unimproved',
            'day_Monday',
            'day_Tuesday',
            'day_Wednesday',
            'day_Thursday',
            'day_Friday',
            'day_Saturday',
            'day_Sunday']

labels = 'accident_yn'

# %%
X = data[features]
y = data[labels]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
f = open('../../data/processed/rf_random.pickle', 'rb')
rf = pickle.load(f)
f.close()

# %%
model = rf.best_estimator_

# %%
df = X_test.copy()

# %%
df['predicted'] = model.predict(X_test)

# %%
results = df.join(y_test)

# %%
df_compare = results.join(data[['segment_id', 'datetime']])

# %%
target_columns = ['segment_id',
                  'datetime',
                  'hour',
                  'daylight_yn',
                  'temp',
                  'wind_speed',
                  'predicted',
                  'accident_yn']

# %%
df_output = df_compare[target_columns].reset_index(drop=True)

# %%
rename_columns = ['segment_id',
                  'date',
                  'hour',
                  'daylight_yn',
                  'temp',
                  'wind_speed',
                  'predicted',
                  'actual']

# %%
df_output.columns = rename_columns

# %%
street_info = pd.read_pickle('../../data/interim/features/streets_by_nhood.pickle')

# %%
street_info = street_info.set_index('segment_id')

# %%
street_class = street_info[['class_Freeway', 'class_Local', 'class_Major Arterial', 'class_Other', 'class_Umimproved']].idxmax(axis=1)

# %%
street_class.name = 'class'

# %%
streets = street_info.join(street_class)

# %%
streets = streets[['fullname', 'class', 'shape_leng', 'geometry']]

# %%
streets['class'] = streets['class'].str[6:]
# Out:
# C:\Users\kgerig\miniconda3\envs\nola-traffic\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
streets
# Out:
#                                    fullname       class    shape_leng  \
# segment_id
# 832.0_1.0                          Avenue A       Local    933.169106
# 832.0_2.0                          Avenue B       Local    699.617547
# 797.0_3.0                        Rue Andr?e       Local    221.205674
# 797.0_4.0                       Rue Colette       Local    449.876776
# 797.0_5.0                      Rue Delphine       Local    511.208548
# 797.0_6.0                        Rue Denise       Local    451.475945
# 832.0_7.0                      Rue Le Ville       Local    136.086814
# 797.0_8.0                      Rue Michelle       Local    451.588233
# 797.0_9.0                        Rue Mignon       Local    451.038027
# 797.0_10.0                       Rue Nadine       Local    221.380264
# 797.0_11.0                      Rue Nichole       Local    451.544905
# 797.0_12.0                Rue Parc Fontaine       Local   1090.102143
# 849.0_14.0                Old Galvez Street       Local     66.481505
# 807.0_15.0                Old Gentilly Road       Local   1988.362754
# 860.0_15.0                Old Gentilly Road       Local  16033.106065
# 832.0_16.0                      10th Street       Local    637.882926
# 832.0_17.0                      12th Street       Local    640.748354
# 832.0_18.0                      14th Street       Local    640.230540
# 832.0_19.0                      16th Street       Local    639.394823
# 832.0_20.0                      18th Street       Local    638.694834
# 832.0_21.0                      20th Street       Local    638.063021
# 832.0_22.0                      22nd Street       Local    637.821961
# 832.0_23.0                      26th Street       Local    635.790277
# 832.0_24.0                      28th Street       Local    635.188792
# 832.0_25.0                      30th Street       Local    633.766628
# 832.0_26.0                      32nd Street       Local    633.853850
# 832.0_27.0                      33rd Street       Local    319.032988
# 832.0_28.0                      34th Street       Local    656.878682
# 832.0_29.0                      35th Street       Local    291.807938
# 832.0_30.0                      36th Street       Local    655.785494
# ...                                     ...         ...           ...
# 815.0_2364.0                Shepherd Street       Local    462.252520
# 848.0_2365.0                  Squire Street  Umimproved    600.785913
# 812.0_2366.0          Star Casino Boulevard       Local    744.323615
# 862.0_2367.0                     Highway 70       Local    961.330018
# 862.0_2368.0                     Highway 72       Local   2082.297487
# 848.0_2369.0               Sunflower Street  Umimproved    333.239130
# 848.0_2370.0                  Taylor Street  Umimproved    896.917700
# 806.0_2371.0  Betty and Charles Turner Lane       Local    234.110909
# 848.0_2372.0                   Tyler Street  Umimproved    893.325078
# 848.0_2373.0                Veronica Street  Umimproved    829.716366
# 848.0_2374.0                  Warren Street  Umimproved    286.203085
# 848.0_2375.0             Weimer Bert Street  Umimproved    681.570708
# 848.0_2376.0                 Yolande Street  Umimproved    799.586405
# 835.0_2378.0                  Choctaw Court       Local   1104.892231
# 839.0_2379.0                     Jane Place       Local     65.927526
# 829.0_2383.0                    Lark Circle       Local     94.483370
# 831.0_2385.0                  Oaktree Drive       Local    297.680153
# 805.0_2386.0    Robert C. Blakes, Sr. Drive       Local    388.672280
# 806.0_2387.0             Henry Thomas Drive       Local   1115.579640
# 812.0_2388.0          Lake Kenilworth Drive       Local    333.119546
# 806.0_2392.0             Dueling Oaks Drive       Local    124.963446
# 795.0_2394.0       Crescent City Connection     Freeway   1342.855656
# 815.0_2394.0       Crescent City Connection     Freeway    709.705479
# 838.0_2394.0       Crescent City Connection     Freeway   3030.841760
# 856.0_2395.0             Timber Haven Drive       Local     39.686142
# 812.0_2396.0                 Welland Street  Umimproved    118.475083
# 856.0_2397.0            Westbank Expressway       Local    460.329214
# 795.0_2398.0              Hubbell Road West       Local    135.344951
# 795.0_2399.0              Hubbell Road East       Local    133.952165
# 806.0_2400.0                Mona Lisa Drive  Umimproved    600.649037
#
#                                                        geometry
# segment_id
# 832.0_1.0     (LINESTRING (-90.116510797142 30.008607463472,...
# 832.0_2.0     (LINESTRING (-90.11746336900001 30.00866154986...
# 797.0_3.0     LINESTRING (-89.99432737558099 29.915348012997...
# 797.0_4.0     (LINESTRING (-89.99589918472201 29.91541454288...
# 797.0_5.0     LINESTRING (-90.00047936777899 29.917374968875...
# 797.0_6.0     LINESTRING (-89.996629116007 29.917237275266, ...
# 832.0_7.0     LINESTRING (-90.11534220490999 30.018289487643...
# 797.0_8.0     LINESTRING (-89.998737710192 29.917325564985, ...
# 797.0_9.0     LINESTRING (-89.99962584102499 29.917359156567...
# 797.0_10.0    LINESTRING (-89.995119220647 29.91538009168, -...
# 797.0_11.0    LINESTRING (-89.997479419236 29.917272798716, ...
# 856.0_2395.0  LINESTRING (-89.999433129499 29.899561099966, ...
# 812.0_2396.0  (LINESTRING (-89.95764293325099 30.06315310793...
# 856.0_2397.0  (LINESTRING (-90.036993471687 29.92895853693, ...
# 795.0_2398.0  LINESTRING (-90.04400216627199 29.95467667709,...
# 795.0_2399.0  LINESTRING (-90.04329694744899 29.954558662224...
# 806.0_2400.0  LINESTRING (-90.092709011655 30.001957251212, ...
#
# [3697 rows x 4 columns]

# %%
# True Positive
df_output.loc[(df_output['predicted'] == 1) & (df_output['actual'] == 1), 'prediction'] = 'True Positive'

# False Positive
df_output.loc[(df_output['predicted'] == 1) & (df_output['actual'] == 0), 'prediction'] = 'False Positive'

# False Negative
df_output.loc[(df_output['predicted'] == 0) & (df_output['actual'] == 1), 'prediction'] = 'False Negative'

# True Negative
df_output.loc[(df_output['predicted'] == 0) & (df_output['actual'] == 0), 'prediction'] = 'True Negative'

# %%
# True Positive
df_output['tp'] = np.where((df_output['predicted'] == 1) & (df_output['actual'] == 1), 1, 0)

# False Positive
df_output['fp'] = np.where((df_output['predicted'] == 1) & (df_output['actual'] == 0), 1, 0)

# False Negative
df_output['fn'] = np.where((df_output['predicted'] == 0) & (df_output['actual'] == 1), 1, 0)

# True Negative
df_output['tn'] = np.where((df_output['predicted'] == 0) & (df_output['actual'] == 0), 1, 0)

# %%
df_output.head()
# Out:
#      segment_id       date  hour  daylight_yn  temp  wind_speed  predicted  \
# 0  812.0_2334.0 2012-11-27    21            0  52.0         9.0          1
# 1   812.0_594.0 2017-02-04     4            0  46.0        13.0          0
# 2   796.0_106.0 2012-02-18    17            1  58.0        14.0          0
# 3  839.0_1034.0 2016-06-29     5            1  80.0         3.0          0
# 4  839.0_2099.0 2017-09-29    10            1  85.0         6.0          1
#
#    actual     prediction  tp  fp  fn  tn
# 0       1  True Positive   1   0   0   0
# 1       0  True Negative   0   0   0   1
# 2       0  True Negative   0   0   0   1
# 3       0  True Negative   0   0   0   1
# 4       1  True Positive   1   0   0   0

# %%
street_accident_predictions = pd.merge(streets, df_output, how='left', on='segment_id')

# %%
street_accident_predictions.columns
# Out:
# Index(['segment_id', 'fullname', 'class', 'shape_leng', 'geometry', 'date',
#        'hour', 'daylight_yn', 'temp', 'wind_speed', 'predicted', 'actual',
#        'prediction', 'tp', 'fp', 'fn', 'tn'],
#       dtype='object')

# %%
street_date_groups = street_accident_predictions[['segment_id', 'date', 'tp', 'fp', 'fn', 'tn']]

# %%
street_date_groups['year'] = street_date_groups.date.dt.year
street_date_groups['month'] = street_date_groups.date.dt.month
# Out:
# C:\Users\kgerig\miniconda3\envs\nola-traffic\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\kgerig\miniconda3\envs\nola-traffic\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
street_date_groups = street_date_groups[['segment_id', 'tp', 'fp', 'fn', 'tn', 'year', 'month']]

# %%
street_predictions = street_date_groups[['segment_id', 'tp', 'fp', 'fn', 'tn']].groupby('segment_id').sum()

# %%
street_output = streets.join(street_predictions)

# %%
street_output = street_output.reset_index()

# %%
street_output.to_pickle('../../data/processed/street_predictions.pickle')
